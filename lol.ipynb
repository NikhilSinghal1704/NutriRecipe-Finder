# %%
import pandas as pd

# %%
data = pd.read_csv('Spoonacular_Analysis.csv')

# %%
data.head(5)
# Out:
#                                                 name  \
# 0  Dim Posto Recipe - Bengali Egg Curry With Popp...
# 1              Roasted Vegetables Pizza Pouch Recipe
# 2  Restaurant Style Paneer Butter Masala Recipe |...
# 3   Shanghai Style Sweet And Spicy Crispy Lotus Stem
# 4                       Mixed Vegetable Handi Recipe
#
#                                          description               cuisine  \
# 0  Dim Posto is a delicious Bengali Style Egg Cur...       Bengali Recipes
# 1  Roasted Vegetables Pizza Pouch is a delicious,...       Italian Recipes
# 2  Paneer Butter Masala also known as Paneer Maka...  North Indian Recipes
# 3  Shanghai Style Sweet And Spicy Crispy Lotus St...               Chinese
# 4  If you feel like eating something exotic, some...  North Indian Recipes
#
#       course         diet                                   ingredients_name  \
# 0     Dinner   Eggetarian  whole eggs, potatoes (aloo), poppy seeds, home...
# ...

# %%
for i in range (580, len(data)):
    data.loc[i, 'spoonacular_analysis'] = None

# %%
data.loc[580, 'spoonacular_analysis']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 data.loc[580, 'spoonacular_analysis'].isnull()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
import json
import ast

# Assuming recipe['spoonacular_analysis'] contains the JSON string
#recipe['spoonacular_analysis'] = recipe['spoonacular_analysis'].apply(ast.literal_eval)

lol = ast.literal_eval(recipe['spoonacular_analysis'])

lol['nutrition']['nutrients']
# Out:
# [{'name': 'Calories',
#   'amount': 1734.4,
#   'unit': 'kcal',
#   'percentOfDailyNeeds': 86.72},
#  {'name': 'Fat', 'amount': 57.94, 'unit': 'g', 'percentOfDailyNeeds': 89.14},
#  {'name': 'Saturated Fat',
#   'amount': 16.33,
#   'unit': 'g',
#   'percentOfDailyNeeds': 102.08},
#  {'name': 'Carbohydrates',
#   'amount': 246.86,
#   'unit': 'g',
#   'percentOfDailyNeeds': 82.29},
#  {'name': 'Net Carbohydrates',
#   'amount': 227.0,
#   'unit': 'g',
#   'percentOfDailyNeeds': 82.55},
#  {'name': 'Sugar', 'amount': 55.35, 'unit': 'g', 'percentOfDailyNeeds': 61.5},
#  {'name': 'Cholesterol',
#   'amount': 100.8,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 33.6},
#  {'name': 'Sodium',
#   'amount': 3128.01,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 136.0},
#  {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g', 'percentOfDailyNeeds': 100.0},
#  {'name': 'Alcohol %',
#   'amount': 0.0,
#   'unit': '%',
#   'percentOfDailyNeeds': 100.0},
#  {'name': 'Protein',
#   'amount': 67.76,
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4984 entries, 0 to 4983
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   name                                    4984 non-null   object
#  1   description                             4983 non-null   object
#  2   cuisine                                 4955 non-null   object
#  3   course                                  4893 non-null   object
#  4   diet                                    4909 non-null   object
#  5   ingredients_name                        4984 non-null   object
#  6   ingredients_quantity                    4984 non-null   object
#  7   prep_time (in mins)                     4969 non-null   float64
#  8   cook_time (in mins)                     4969 non-null   float64
#  9   instructions                            4984 non-null   object
# ...

# %%
data.to_csv('Spoonacular_Analysis.csv', index=False)
